# %% [markdown]
# 5/17/24
# Youtube Video Notes: Working With APIs in Python - Pagination and Data Extraction

# %% [markdown]
# https://www.youtube.com/watch?v=-oPuGc05Lxs

# %%
#using the rick and morty api: https://rickandmortyapi.com/api/
{
    "characters":"https://rickandmortyapi.com/api/character",
    "locations":"https://rickandmortyapi.com/api/location",
    "episodes":"https://rickandmortyapi.com/api/episode"
 }
#each of these are endpoints
# Out:
# {'characters': 'https://rickandmortyapi.com/api/character',
#  'locations': 'https://rickandmortyapi.com/api/location',
#  'episodes': 'https://rickandmortyapi.com/api/episode'}

# %%
import requests

baseurl = "https://rickandmortyapi.com/api/"
endpoint = "character"

r = requests.get(baseurl + endpoint) #both are strings so can concatenate w/ a +

#print(r) #<Response [200]> we don't want this https request, we want the data
print(r.json()) #json response to get the information within r, prints the stuff shown in the browser
# Out:
# {'info': {'count': 826, 'pages': 42, 'next': 'https://rickandmortyapi.com/api/character?page=2', 'prev': None}, 'results': [{'id': 1, 'name': 'Rick Sanchez', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://
# ...

# %%
data = r.json()
print(data["info"]) #access specific parts of the json. asked for info key here

#want how many pages there are, save as 
pages = print(data["info"]['pages']) #42
# Out:
# {'count': 826, 'pages': 42, 'next': 'https://rickandmortyapi.com/api/character?page=2', 'prev': None}
# 42

# %%
print(data['results'][0]) #asked for first item in the list of results in data. has id and name, as well as other info

#save first item (a character)'s name and episodes info separately
name = data['results'][0]['name']
episodes = data['results'][0]['episode']

#episodes looks like:
print(episodes)

#how many eps was this character in?
len(episodes) #
# Out:
# {'id': 1, 'name': 'Rick Sanchez', 'status': 'Alive', 'species': 'Human', 'type': '', 'gender': 'Male', 'origin': {'name': 'Earth (C-137)', 'url': 'https://rickandmortyapi.com/api/location/1'}, 'location': {'name': 'Citadel of Ricks', 'url': 'https://rickandmortyapi.com/api/location/3'}, 'image': 'https://rickandmortyapi.com/api/character/avatar/1.jpeg', 'episode': ['https://rickandmortyapi.com/api/episode/1', 'https://rickandmortyapi.com/api/episode/2', 'https://rickandmortyapi.com/api/episode/3', 'https://rickandmortyapi.com/api/episode/4', 'https://rickandmortyapi.com/api/episode/5', 'https://rickandmortyapi.com/api/episode/6', 'https://rickandmortyapi.com/api/episode/7', 'https://rickandmortyapi.com/api/episode/8', 'https://rickandmortyapi.com/api/episode/9', 'https://rickandmortyapi.com/api/episode/10', 'https://rickandmortyapi.com/api/episode/11', 'https://rickandmortyapi.com/api/episode/12', 'https://rickandmortyapi.com/api/episode/13', 'https://rickandmortyapi.com/api/episode/
# ...

# %%
#save to computer

import json

# Serializing json
json_object = json.dumps(episodes, indent=4)
 
# Writing to sample.json
with open("episodes.json", "w") as outfile:
    outfile.write(json_object)

# %%
#make all the above into a function

baseurl = "https://rickandmortyapi.com/api/"
endpoint = "character"

def main_request(baseurl, endpoint, x):     #can also specify page number like this, so it can reference the page #'s shown in the api website
    r = requests.get(baseurl + endpoint + f'?page={x}')
    return r.json()

def get_pages(response):
    pages = data['info']['pages']
    return pages

def parse_json(response):
    for item in response['results']:   # we want to loop, not just get the first item. so instead of data['results'][0]['episode']
        print(item['name'], len(item['episode']))   #prints name of character and # of episodes for each character
        # name = data['name']
        # episodes = data['results']['episode']
    return

#make dictionary list of characters w/ their respective info
def parse_json(response):
    charlist = [] 
    for item in response['results']:     #make dictionary
        char = {
            'name': item['name'],
            'num_ep': len(item['episode'])
        }
        charlist.append(char)            #append character to character list
    return charlist                    #return character list


data = main_request(baseurl, endpoint, 2)    #the 1 at the end lets us work with just page 1

mainlist = []

#use get_pages to figure out how many pages there are, then store the info in total # pages into json
for x in range(get_pages(data)+1):
    #print(x)   #outputs 42 total pages
    mainlist.extend(parse_json(main_request(baseurl, endpoint, x)))  #parse all 42 pgs, add all of that into new list mainlist

print("Mainlist:", len(mainlist)) #make sure you're adding the right information

print("Character list:", parse_json(data))
print("Number of Characters on this page:", len(parse_json(data)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 40
#      37 #use get_pages to figure out how many pages there are, then store the info in total # pages into json
#      38 for x in range(get_pages(data)+1):
#      39     #print(x)   #outputs 42 total pages
# ---> 40     mainlist.extend(parse_json(main_request(baseurl, endpoint, x)))  #parse all 42 pgs, add all of that into new list mainlist
#      42 print("Mainlist:", len(mainlist)) #make sure you're adding the right information
#      44 print("Character list:", parse_json(data))
#
# Cell In[46], line 7, in main_request(baseurl, endpoint, x)
#       6 def main_request(baseurl, endpoint, x):     #can also specify page number like this, so it can reference the page #'s shown in the api website
# ----> 7     r = requests.get(baseurl + endpoint + f'?page={x}')
#       8     return r.json()
#
# ...
